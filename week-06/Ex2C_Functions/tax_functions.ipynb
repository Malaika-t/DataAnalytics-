# %% [markdown]
# # Exercise 2.C Creating and calling functions
# ## Lab 3. Tax Functions

# %%
def get_soc_sec_tax(gross_pay):
    return gross_pay * 0.062

# %%
def get_medicare_tax(gross_pay):
    return gross_pay * 0.0145

# %%
def get_federal_tax(gross_pay, withholding_code):
    if withholding_code == 0:
        rate = 0.23
    elif withholding_code == 1:
        rate = 0.21
    elif withholding_code == 2:
        rate = 0.195
    elif withholding_code == 3:
        rate = 0.185
    else:
        rate = 0.18 - ((withholding_code -4) * 0.005)

    return gross_pay * rate

# %%
# Test Cell - Person 1:
gp =750
print(f"SS Tax: ${get_soc_sec_tax(gp)}")
print(f"Medicare Tax: ${get_medicare_tax(gp)}")
print(f"Federal Tax: ${get_federal_tax(gp, 0)}")
# Out:
# SS Tax: $46.5
# Medicare Tax: $10.875
# Federal Tax: $172.5

# %%
# Test Cell - Person 2:
gp =1550
print(f"SS Tax: ${get_soc_sec_tax(gp)}")
print(f"Medicare Tax: ${get_medicare_tax(gp)}")
print(f"Federal Tax: ${get_federal_tax(gp, 2)}")
# Out:
# SS Tax: $96.1
# Medicare Tax: $22.475
# Federal Tax: $302.25

# %%
# Test Cell - Person 3:
gp =1100
print(f"SS Tax: ${get_soc_sec_tax(gp)}")
print(f"Medicare Tax: ${get_medicare_tax(gp):.2f}")
print(f"Federal Tax: ${get_federal_tax(gp, 5)}")
# Out:
# SS Tax: $68.2
# Medicare Tax: $15.95
# Federal Tax: $192.5
